# %%
# !pip install flair
# Out:
# Collecting flair
#   Downloading flair-0.13.0-py3-none-any.whl (387 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.2/387.2 kB 6.2 MB/s eta 0:00:00
# Collecting boto3>=1.20.27 (from flair)
#   Downloading boto3-1.33.6-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 8.0 MB/s eta 0:00:00
# Collecting bpemb>=0.3.2 (from flair)
#   Downloading bpemb-0.3.4-py3-none-any.whl (19 kB)
# Collecting conllu>=4.0 (from flair)
#   Downloading conllu-4.5.3-py2.py3-none-any.whl (16 kB)
# Collecting deprecated>=1.2.13 (from flair)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting ftfy>=6.1.0 (from flair)
#   Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: gdown>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from flair) (4.6.6)
# Requirement already satisfied: gensim>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from flair) (4.3.2)
# Requirement already satisfied: huggingface-hub>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from flair) (0.19.4)
# Collecting janome>=0.4.2 (from flair)
#   Downloading Janome-0.5.0-py2.py3-none-any.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 54.9 MB/s eta 0:00:00
# Collecting langdetect>=1.0.9 (from flair)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 69.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from flair) (4.9.3)
# Requirement already satisfied: matplotlib>=2.2.3 in /usr/local/lib/python3.10/dist-packages (from flair) (3.7.1)
# Requirement already satisfied: more-itertools>=8.13.0 in /usr/local/lib/python3.10/dist-packages (from flair) (10.1.0)
# Collecting mpld3>=0.3 (from flair)
#   Downloading mpld3-0.5.9-py3-none-any.whl (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.2/201.2 kB 25.4 MB/s eta 0:00:00
# Collecting pptree>=3.1 (from flair)
#   Downloading pptree-3.1.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from flair) (2.8.2)
# Collecting pytorch-revgrad>=0.2.0 (from flair)
#   Downloading pytorch_revgrad-0.2.0-py3-none-any.whl (4.6 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from flair) (2023.6.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from flair) (1.2.2)
# Collecting segtok>=1.5.11 (from flair)
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Collecting sqlitedict>=2.0.0 (from flair)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate>=0.8.10 in /usr/local/lib/python3.10/dist-packages (from flair) (0.9.0)
# Requirement already satisfied: torch!=1.8,>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from flair) (2.1.0+cu118)
# Requirement already satisfied: tqdm>=4.63.0 in /usr/local/lib/python3.10/dist-packages (from flair) (4.66.1)
# Collecting transformer-smaller-training-vocab>=0.2.3 (from flair)
#   Downloading transformer_smaller_training_vocab-0.3.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: transformers[sentencepiece]<5.0.0,>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from flair) (4.35.2)
# Collecting urllib3<2.0.0,>=1.0.0 (from flair)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 16.7 MB/s eta 0:00:00
# Collecting wikipedia-api>=0.5.7 (from flair)
#   Downloading Wikipedia_API-0.6.0-py3-none-any.whl (14 kB)
# Collecting semver<4.0.0,>=3.0.0 (from flair)
#   Downloading semver-3.0.2-py3-none-any.whl (17 kB)
# Collecting botocore<1.34.0,>=1.33.6 (from boto3>=1.20.27->flair)
#   Downloading botocore-1.33.6-py3-none-any.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 69.5 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.20.27->flair)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.9.0,>=0.8.2 (from boto3>=1.20.27->flair)
#   Downloading s3transfer-0.8.2-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bpemb>=0.3.2->flair) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bpemb>=0.3.2->flair) (2.31.0)
# Collecting sentencepiece (from bpemb>=0.3.2->flair)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 59.2 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.13->flair) (1.14.1)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy>=6.1.0->flair) (0.2.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown>=4.4.0->flair) (3.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown>=4.4.0->flair) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=4.4.0->flair) (4.11.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.2.0->flair) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.2.0->flair) (6.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->flair) (2023.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->flair) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->flair) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->flair) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (3.1.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mpld3>=0.3->flair) (3.1.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->flair) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->flair) (3.2.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.5.0->flair) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.5.0->flair) (3.2.1)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.5.0->flair) (2.1.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair) (0.4.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair) (3.20.3)
# Collecting accelerate>=0.20.3 (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair)
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 26.7 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=4.4.0->flair) (2.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mpld3>=0.3->flair) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb>=0.3.2->flair) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb>=0.3.2->flair) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb>=0.3.2->flair) (2023.11.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb>=0.3.2->flair) (1.7.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.8,>=1.5.0->flair) (1.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->transformers[sentencepiece]<5.0.0,>=4.18.0->flair) (5.9.5)
# Building wheels for collected packages: langdetect, pptree, sqlitedict
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993225 sha256=72a7d6ca28b106bab8c92e26a9232c3d8289be8213be60fa3e0e92e455c45070
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for pptree (setup.py) ... done
#   Created wheel for pptree: filename=pptree-3.1-py3-none-any.whl size=4608 sha256=9eba46ea52c93fb5d8de17b4dafb3fa2469eaa29f4971baae527cd920baef3de
#   Stored in directory: /root/.cache/pip/wheels/9f/b6/0e/6f26eb9e6eb53ff2107a7888d72b5a6a597593956113037828
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16863 sha256=43e594600ec33edc82c8791af62f10fca4107c9bf4afa7a38ddf78257b933140
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
# Successfully built langdetect pptree sqlitedict
# Installing collected packages: sqlitedict, sentencepiece, pptree, janome, urllib3, semver, segtok, langdetect, jmespath, ftfy, deprecated, conllu, botocore, wikipedia-api, s3transfer, pytorch-revgrad, mpld3, bpemb, boto3, accelerate, transformer-smaller-training-vocab, flair
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
# Successfully installed accelerate-0.25.0 boto3-1.33.6 botocore-1.33.6 bpemb-0.3.4 conllu-4.5.3 deprecated-1.2.14 flair-0.13.0 ftfy-6.1.3 janome-0.5.0 jmespath-1.0.1 langdetect-1.0.9 mpld3-0.5.9 pptree-3.1 pytorch-revgrad-0.2.0 s3transfer-0.8.2 segtok-1.5.11 semver-3.0.2 sentencepiece-0.1.99 sqlitedict-2.1.0 transformer-smaller-training-vocab-0.3.2 urllib3-1.26.18 wikipedia-api-0.6.0

# %%
import pandas as pd
dataset=pd.read_csv("tesr.csv")

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
from nltk.tokenize import word_tokenize

# Assuming 'source' and 'target' are the columns containing text
source_text = dataset['source'].astype(str)  # Assuming df is your DataFrame
target_text = dataset['target'].astype(str)

# Tokenizing using NLTK
source_tokens = source_text.apply(word_tokenize)
target_tokens = target_text.apply(word_tokenize)

# %%
# !pip  install -U farasapy
# Out:
# Collecting farasapy
#   Downloading farasapy-0.0.14-py3-none-any.whl (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from farasapy) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from farasapy) (4.66.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->farasapy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->farasapy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->farasapy) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->farasapy) (2023.11.17)
# Installing collected packages: farasapy
# Successfully installed farasapy-0.0.14

# %%
from farasa.stemmer import FarasaStemmer

# Initialize FarasaStemmer
farasa_stemmer = FarasaStemmer(interactive=True)

def apply_stemming(tokens):
    stemmed_tokens = []
    for token in tokens:
        stemmed_token = farasa_stemmer.stem(token)
        stemmed_tokens.append(stemmed_token)
    return stemmed_tokens

source_tokens = source_tokens.apply(apply_stemming)
target_tokens = target_tokens.apply(apply_stemming)
# Out:
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1061: InsecureRequestWarning: Unverified HTTPS request is being made to host 'farasa-api.qcri.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████| 241M/241M [00:33<00:00, 7.29MiB/s]
# [2023-12-03 19:30:35,806 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.

# %%
from nltk.corpus import stopwords

nltk.download('stopwords')  # Download stopwords

# Arabic stopwords
arabic_stopwords = set(stopwords.words('arabic'))

def remove_stopwords(tokens):
    clean_tokens = [token for token in tokens if token not in arabic_stopwords]
    return clean_tokens

source_tokens = source_tokens.apply(remove_stopwords)
target_tokens = target_tokens.apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def remove_blanks(tokens):
    return [token for token in tokens if token.strip()]

source_tokens = source_tokens.apply(remove_blanks)
target_tokens = target_tokens.apply(remove_blanks)

# %%
# Printing preprocessed tokens from 'source' and 'target' columns
for idx in range(len(dataset)):  # Assuming 'df' is your DataFrame
    print(f"Source Text {idx + 1}:")
    print(source_tokens[idx])
    print("\nTarget Text:")
    print(target_tokens[idx])
    print("\n---------------------\n")
# Out:
# Source Text 1:
# ['بسم', 'الله', 'رحمن', 'رحيم']
#
# Target Text:
# ['جاء', 'رسول', 'عزيز', 'عنت', 'حريص', 'مؤمن', 'رءوف', 'رحيم']
#
# ---------------------
#
# Source Text 2:
# ['بسم', 'الله', 'رحمن', 'رحيم']
#
# Target Text:
# ['قال', 'اركب', 'بسم', 'الله', 'مجرى', 'مرسا', 'رب', 'غفور', 'رحيم']
#
# ---------------------
#
# Source Text 3:
# ['بسم', 'الله', 'رحمن', 'رحيم']
#
# Target Text:
# ['نعمة', 'الله', 'مس', 'ضر', 'جأر']
#
# ---------------------
#
# Source Text 4:
# ['بسم', 'الله', 'رحمن', 'رحيم']
#
# Target Text:
# ['رحمن', 'عرش', 'استوى']
#
# ---------------------
#
# Source Text 5:
# ['بسم', 'الله', 'رحمن', 'رحيم']
#
# Target Text:
# ['سبح', 'اسم', 'رب', 'عظيم']
#
# ---------------------
#
# Source Text 6:
# ['حمد', 'الله', 'رب', 'عالم']
#
# Target Text:
# ['قال', 'فرعون', 'رب', 'عالم']
#
# ---------------------
#
# Source Text 7:
# ['مالك', 'يوم', 'دين']
#
# Target Text:
# ['ورث', 'أرض']
#
# ---------------------
#
# Source Text 8:
# ['مالك', 'يوم', 'دين']
#
# Target Text:
# ['ملك', 'يومئذ', 'حق', 'رحمن', 'يوم', 'كافر', 'عسير']
#
# ---------------------
#
# Source Text 9:
# ['مالك', 'يوم', 'دين']
#
# Target Text:
# ['أإذا', 'مات', 'تراب', 'عظمة', 'أإنا', 'مدين']
#
# ---------------------
#
# Source Text 10:
# ['مالك', 'يوم', 'دين']
#
# Target Text:
# ['يوم', 'بارز', 'خفي', 'الله', 'شيء', 'ملك', 'يوم', 'الله', 'قهار']
#
# ---------------------
#
# Source Text 11:
# ['كتاب', 'ريب', 'هدى', 'متقي']
#
# Target Text:
# ['تنزيل', 'كتاب', 'ريب', 'رب', 'عالم']
#
# ---------------------
#
# Source Text 12:
# ['آمن', 'أنزل', 'أنزل', 'آخرة', 'يوقن']
#
# Target Text:
# ['آتى', 'كتاب', 'آمن']
#
# ---------------------
#
# Source Text 13:
# ['آمن', 'أنزل', 'أنزل', 'آخرة', 'يوقن']
#
# Target Text:
# ['خلق']
#
# ---------------------
#
# Source Text 14:
# ['آمن', 'أنزل', 'أنزل', 'آخرة', 'يوقن']
#
# Target Text:
# ['قدر', 'هدى']
#
# ---------------------
#
# Source Text 15:
# ['آمن', 'أنزل', 'أنزل', 'آخرة', 'يوقن']
#
# Target Text:
# ['أخرج', 'مرعى']
#
# ---------------------
#
# Source Text 16:
# ['آمن', 'أنزل', 'أنزل', 'آخرة', 'يوقن']
#
# Target Text:
# ['غثاء', 'أحوى']
#
# ---------------------
#
# Source Text 17:
# ['كفر', 'سواء', 'أأنذرتهم', 'أنذر', 'آمن']
#
# Target Text:
# ['حق', 'كلم', 'رب', 'آمن']
#
# ---------------------
#
# Source Text 18:
# ['كفر', 'سواء', 'أأنذرتهم', 'أنذر', 'آمن']
#
# Target Text:
# ['جهنم', 'صلى', 'قرار']
#
# ---------------------
#
# Source Text 19:
# ['ختم', 'الله', 'قلب', 'سمع', 'أبصار', 'غشاو', 'عذاب', 'عظيم']
#
# Target Text:
# ['أحور']
#
# ---------------------
#
# Source Text 20:
# ['ختم', 'الله', 'قلب', 'سمع', 'أبصار', 'غشاو', 'عذاب', 'عظيم']
#
# Target Text:
# ['ران', 'قلب', 'كسب']
#
# ---------------------
#
# Source Text 21:
# ['ظن', 'ملاقو', 'رب', 'راجع']
#
# Target Text:
# ['ظن', 'ملاق', 'حساب']
#
# ---------------------
#
# Source Text 22:
# ['اتقى', 'يوم', 'جزى', 'شيء', 'شفاعة', 'يؤخذ', 'عدل', 'نصر']
#
# Target Text:
# ['قفو', 'مسؤول']
#
# ---------------------
#
# Source Text 23:
# ['نكال', 'يد', 'موعظة', 'متقي']
#
# Target Text:
# ['الله', 'نكال', 'آخرة', 'أولى']
#
# ---------------------
#
# Source Text 24:
# ['قال', 'اضربوه', 'أحيى', 'الله', 'ميت', 'يريكم', 'آية', 'عقل']
#
# Target Text:
# ['أكل', 'ثمر', 'عملة', 'يد', 'أفل', 'شكر']
#
# ---------------------
#
# Source Text 25:
# ['أسلم', 'وجه', 'الله', 'محسن', 'أجر', 'رب', 'خوف', 'حزن']
#
# Target Text:
# ['ويل', 'مصلي']
#
# ---------------------
#
# Source Text 26:
# ['قال', 'الله', 'ولد', 'سماء', 'أرض', 'قانتون']
#
# Target Text:
# ['قال', 'رحمن', 'ولد']
#
# ---------------------
#
# Source Text 27:
# ['قال', 'الله', 'ولد', 'سماء', 'أرض', 'قانتون']
#
# Target Text:
# ['انبغى', 'رحمن', 'ولد']
#
# ---------------------
#
# Source Text 28:
# ['قال', 'الله', 'ولد', 'سماء', 'أرض', 'قانتون']
#
# Target Text:
# ['ولد', 'ولد']
#
# ---------------------
#
# Source Text 29:
# ['بديع', 'سماء', 'أرض', 'قضى', 'أمر', 'قال']
#
# Target Text:
# ['عيسى', 'الله', 'آدم', 'خلق', 'تراب', 'قال']
#
# ---------------------
#
# Source Text 30:
# ['بديع', 'سماء', 'أرض', 'قضى', 'أمر', 'قال']
#
# Target Text:
# ['قول', 'شيء', 'أراد', 'قال']
#
# ---------------------
#
# Source Text 31:
# ['بديع', 'سماء', 'أرض', 'قضى', 'أمر', 'قال']
#
# Target Text:
# ['أمر', 'أراد', 'شيء', 'قال']
#
# ---------------------
#
# Source Text 32:
# ['وصى', 'إبراهيم', 'بنون', 'يعقوب', 'بنون', 'الله', 'اصطفى', 'دين', 'تموتن', 'مسلم']
#
# Target Text:
# ['بخل', 'استغنى']
#
# ---------------------
#
# Source Text 33:
# ['وصى', 'إبراهيم', 'بنون', 'يعقوب', 'بنون', 'الله', 'اصطفى', 'دين', 'تموتن', 'مسلم']
#
# Target Text:
# ['كذب', 'أحسن']
#
# ---------------------
#
# Source Text 34:
# ['وصى', 'إبراهيم', 'بنون', 'يعقوب', 'بنون', 'الله', 'اصطفى', 'دين', 'تموتن', 'مسلم']
#
# Target Text:
# ['يسر', 'عسرى']
#
# ---------------------
#
# Source Text 35:
# ['تولى', 'سعى', 'أرض', 'أفسد', 'أهلك', 'حرث', 'نسل', 'الله', 'أحب', 'فساد']
#
# Target Text:
# ['عبرة', 'خشي']
#
# ---------------------
#
# Source Text 36:
# ['نظر', 'أتى', 'الله', 'ظلل', 'غمام', 'ملأك', 'قضي', 'أمر', 'الله', 'أمر']
#
# Target Text:
# ['جاء', 'رب', 'ملك', 'صف', 'صف']
#
# ---------------------
#
# Source Text 37:
# ['متاع', 'قليل', 'مأوى', 'جهنم', 'مهاد']
#
# Target Text:
# ['متاع', 'دنيا', 'مرجع', 'نذيق', 'عذاب', 'شديد', 'كفر']
#
# ---------------------
#
# Source Text 38:
# ['متاع', 'قليل', 'مأوى', 'جهنم', 'مهاد']
#
# Target Text:
# ['نمتع', 'قليل', 'اضطر', 'عذاب', 'غليظ']
#
# ---------------------
#
# Source Text 39:
# ['الله', 'يظلم', 'مثقال', 'ذرة', 'تك', 'حسن', 'ضاعف', 'آتى', 'أجر', 'عظيم']
#
# Target Text:
# ['جاء', 'حسن', 'جاء', 'سيئة', 'جزى', 'ظلم']
#
# ---------------------
#
# Source Text 40:
# ['الله', 'يظلم', 'مثقال', 'ذرة', 'تك', 'حسن', 'ضاعف', 'آتى', 'أجر', 'عظيم']
#
# Target Text:
# ['نفخ', 'صور', 'نسب', 'يومئذ', 'تساءل']
#
# ---------------------
#
# Source Text 41:
# ['رد', 'الله', 'مولى', 'حق', 'حكم', 'أسرع', 'حاسب']
#
# Target Text:
# ['لمجموعون', 'ميقات', 'يوم', 'معلوم']
#
# ---------------------
#
# Source Text 42:
# ['أدرك', 'أبصار', 'أدرك', 'أبصار', 'لطيف', 'خبير']
#
# Target Text:
# ['خلق', 'لطيف', 'خبير']
#
# ---------------------
#
# Source Text 43:
# ['أدرك', 'أبصار', 'أدرك', 'أبصار', 'لطيف', 'خبير']
#
# Target Text:
# ['وجه', 'يومئذ', 'ناضر']
#
# ---------------------
#
# Source Text 44:
# ['شاء', 'الله', 'أشرك', 'حفيظ', 'وكيل']
#
# Target Text:
# ['ذكر', 'مذكر']
#
# ---------------------
#
# Source Text 45:
# ['كذب', 'قال', 'رب', 'رحمة', 'واسع', 'رد', 'بأس', 'قوم', 'مجرم']
#
# Target Text:
# ['بطش', 'رب', 'شديد']
#
# ---------------------
#
# Source Text 46:
# ['قرية', 'أهلك', 'جاء', 'بأس', 'بيات', 'قائل']
#
# Target Text:
# ['أفأمن', 'أهل', 'قرية', 'أتى', 'بأس', 'بيات', 'نائم']
#
# ---------------------
#
# Source Text 47:
# ['قرية', 'أهلك', 'جاء', 'بأس', 'بيات', 'قائل']
#
# Target Text:
# ['أوأمن', 'أهل', 'قرية', 'أتى', 'بأس', 'ضحى', 'لعب']
#
# ---------------------
#
# Source Text 48:
# ['قرية', 'أهلك', 'جاء', 'بأس', 'بيات', 'قائل']
#
# Target Text:
# ['أفأمن', 'مكر', 'سيئة', 'خسف', 'الله', 'أرض', 'أتى', 'عذاب', 'شعر']
#
# ---------------------
#
# Source Text 49:
# ['قرية', 'أهلك', 'جاء', 'بأس', 'بيات', 'قائل']
#
# Target Text:
# ['قرية', 'أهلك', 'ظالم', 'خاوي', 'عرش', 'بئر', 'معطل', 'قصر', 'مشيد']
#
# ---------------------
#
# Source Text 50:
# ['دعوى', 'جاء', 'بأس', 'قال', 'ظالم']
#
# Target Text:
# ['قال', 'ويل', 'ظالم']
#
# ---------------------
#
# Source Text 51:
# ['قال', 'تحي', 'مات', 'خرج']
#
# Target Text:
# ['خلق', 'أعاد', 'أخرج', 'آخر']
#
# ---------------------
#
# Source Text 52:
# ['عبد', 'الله', 'نذير', 'بشير']
#
# Target Text:
# ['أرسل', 'رسول', 'نوح', 'إله', 'فاعبدون']
#
# ---------------------
#
# Source Text 53:
# ['الله', 'بسط', 'شاء', 'قدر', 'فرح', 'حياة', 'دنيا', 'حياة', 'دنيا', 'آخرة', 'متاع']
#
# Target Text:
# ['آخرة', 'خير', 'أبقى']
#
# ---------------------
#
# Source Text 54:
# ['خلق', 'إنسان', 'نطفة', 'خصيم', 'مبين']
#
# Target Text:
# ['أولم', 'إنسان', 'خلق', 'نطفة', 'خصيم', 'مبين']
#
# ---------------------
#
# Source Text 55:
# ['خلق', 'إنسان', 'نطفة', 'خصيم', 'مبين']
#
# Target Text:
# ['ضرب', 'نسي', 'خلق', 'قال', 'أحيى', 'عظمة', 'رميم']
#
# ---------------------
#
# Source Text 56:
# ['خلق', 'إنسان', 'نطفة', 'خصيم', 'مبين']
#
# Target Text:
# ['قال', 'أحيى', 'مرة', 'خلق', 'عليم']
#
# ---------------------
#
# Source Text 57:
# ['حمل', 'أثقال', 'بلد', 'بالغ', 'شق', 'رب', 'رءوف', 'رحيم']
#
# Target Text:
# ['أنعام', 'خلق', 'دفء', 'منفعة', 'أكل']
#
# ---------------------
#
# Source Text 58:
# ['حمل', 'أثقال', 'بلد', 'بالغ', 'شق', 'رب', 'رءوف', 'رحيم']
#
# Target Text:
# ['أنعام', 'عبرة', 'نسق', 'بطون', 'منفعة', 'كثير', 'أكل']
#
# ---------------------
#
# Source Text 59:
# ['حمل', 'أثقال', 'بلد', 'بالغ', 'شق', 'رب', 'رءوف', 'رحيم']
#
# Target Text:
# ['فلك', 'حمل']
#
# ---------------------
#
# Source Text 60:
# ['حمل', 'أثقال', 'بلد', 'بالغ', 'شق', 'رب', 'رءوف', 'رحيم']
#
# Target Text:
# ['أولم', 'خلق', 'عمل', 'يد', 'أنعام', 'مالك']
#
# ---------------------
#
# Source Text 61:
# ['حمل', 'أثقال', 'بلد', 'بالغ', 'شق', 'رب', 'رءوف', 'رحيم']
#
# Target Text:
# ['ذلل', 'ركوب', 'أكل']
#
# ---------------------
#
# Source Text 62:
# ['ألقى', 'أرض', 'راسي', 'ماد', 'نهر', 'سبيل', 'اهتدى']
#
# Target Text:
# ['أرض', 'راسي', 'ماد', 'فج', 'سبيل', 'اهتدى']
#
# ---------------------
#
# Source Text 63:
# ['ألقى', 'أرض', 'راسي', 'ماد', 'نهر', 'سبيل', 'اهتدى']
#
# Target Text:
# ['جبل', 'أرسى']
#
# ---------------------
#
# Source Text 64:
# ['يوم', 'بعث', 'أمة', 'شهيد', 'أذن', 'كفر', 'يستعتبون']
#
# Target Text:
# ['يوم', 'نطق']
#
# ---------------------
#
# Source Text 65:
# ['قال', 'أإذا', 'عظمة', 'رفات', 'أإنا', 'مبعوث', 'خلق', 'جديد']
#
# Target Text:
# ['أإذا', 'عظمة', 'نخر']
#
# ---------------------
#
# Source Text 66:
# ['قال', 'أإذا', 'عظمة', 'رفات', 'أإنا', 'مبعوث', 'خلق', 'جديد']
#
# Target Text:
# ['قال', 'كرة', 'خاسر']
#
# ---------------------
#
# Source Text 67:
# ['يوم', 'دعا', 'فتستجيبون', 'حمد', 'ظن', 'لبث', 'قليل']
#
# Target Text:
# ['يتخافتون', 'لبث']
#
# ---------------------
#
# Source Text 68:
# ['يوم', 'دعا', 'فتستجيبون', 'حمد', 'ظن', 'لبث', 'قليل']
#
# Target Text:
# ['قال', 'قال', 'أمثل', 'طريقة', 'لبث', 'يوم']
#
# ---------------------
#
# Source Text 69:
# ['يوم', 'دعا', 'فتستجيبون', 'حمد', 'ظن', 'لبث', 'قليل']
#
# Target Text:
# ['قال', 'لبث', 'أرض', 'عدد', 'سنة']
#
# ---------------------
#
# Source Text 70:
# ['يوم', 'دعا', 'فتستجيبون', 'حمد', 'ظن', 'لبث', 'قليل']
#
# Target Text:
# ['قال', 'لبث', 'يوم', 'يوم', 'اسأل', 'عادي']
#
# ---------------------
#
# Source Text 71:
# ['يوم', 'دعا', 'فتستجيبون', 'حمد', 'ظن', 'لبث', 'قليل']
#
# Target Text:
# ['قال', 'لبث', 'قليل']
#
# ---------------------
#
# Source Text 72:
# ['يوم', 'دعا', 'فتستجيبون', 'حمد', 'ظن', 'لبث', 'قليل']
#
# Target Text:
# ['يوم', 'لبث', 'عشية', 'ضحا']
#
# ---------------------
#
# Source Text 73:
# ['يوم', 'سار', 'جبل', 'راوند', 'أرض', 'بارز', 'وحشرناهم', 'نغادر']
#
# Target Text:
# ['سأل', 'جبل', 'قال', 'نسف', 'رب', 'نسف']
#
# ---------------------
#
# Source Text 74:
# ['يوم', 'سار', 'جبل', 'راوند', 'أرض', 'بارز', 'وحشرناهم', 'نغادر']
#
# Target Text:
# ['سار', 'جبل', 'سير']
#
# ---------------------
#
# Source Text 75:
# ['يوم', 'سار', 'جبل', 'راوند', 'أرض', 'بارز', 'وحشرناهم', 'نغادر']
#
# Target Text:
# ['جبل', 'عهن', 'منفوش']
#
# ---------------------
#
# Source Text 76:
# ['أوحى', 'عذاب', 'كذب', 'تولى']
#
# Target Text:
# ['كذب', 'تولى']
#
# ---------------------
#
# Source Text 77:
# ['قال', 'رب', 'شيء', 'خلق', 'هدى']
#
# Target Text:
# ['قدر', 'هدى']
#
# ---------------------
#
# Source Text 78:
# ['اجتبا', 'رب', 'تاب', 'هدى']
#
# Target Text:
# ['لقي', 'آدم', 'رب', 'كلمة', 'تاب', 'تواب', 'رحيم']
#
# ---------------------
#
# Source Text 79:
# ['أمة', 'أمة', 'رب', 'فاعبدون']
#
# Target Text:
# ['أمة', 'أمة', 'رب', 'اتق']
#
# ---------------------
#
# Source Text 80:
# ['أرسل', 'رحمة', 'عالم']
#
# Target Text:
# ['جهنم', 'صلى', 'قرار']
#
# ---------------------
#
# Source Text 81:
# ['قدر', 'الله', 'حق', 'قدر', 'الله', 'قوي', 'عزيز']
#
# Target Text:
# ['الله', 'رزاق', 'قوة', 'متين']
#
# ---------------------
#
# Source Text 82:
# ['قدر', 'الله', 'حق', 'قدر', 'الله', 'قوي', 'عزيز']
#
# Target Text:
# ['بطش', 'رب', 'شديد']
#
# ---------------------
#
# Source Text 83:
# ['قدر', 'الله', 'حق', 'قدر', 'الله', 'قوي', 'عزيز']
#
# Target Text:
# ['يبدئ', 'أعاد']
#
# ---------------------
#
# Source Text 84:
# ['زكاة', 'فاعل']
#
# Target Text:
# ['أفلح', 'زكى']
#
# ---------------------
#
# Source Text 85:
# ['قال', 'رب', 'انصرني', 'كذب']
#
# Target Text:
# ['دعا', 'رب', 'مغلوب', 'انتصر']
#
# ---------------------
#
# Source Text 86:
# ['ذر', 'غمرة']
#
# Target Text:
# ['مهل', 'كافر', 'أمهل', 'رويد']
#
# ---------------------
#
# Source Text 87:
# ['مترف', 'عذاب', 'جأر']
#
# Target Text:
# ['نكل', 'جحيم']
#
# ---------------------
#
# Source Text 88:
# ['نفخ', 'صور', 'نسب', 'يومئذ', 'تساءل']
#
# Target Text:
# ['سأل', 'حميم', 'حميم']
#
# ---------------------
#
# Source Text 89:
# ['رب', 'أخرج', 'ظالم']
#
# Target Text:
# ['اعترف', 'ذنب', 'سحق', 'صاحب', 'سعير']
#
# ---------------------
#
# Source Text 90:
# ['أفحسبتم', 'أنما', 'خلق', 'عبث', 'أرجع']
#
# Target Text:
# ['أيحسب', 'إنسان', 'سدى']
#
# ---------------------
#
# Source Text 91:
# ['صاحب', 'جنة', 'يومئذ', 'خير', 'مستقر', 'أحسن', 'مقيل']
#
# Target Text:
# ['خالد', 'حسن', 'مستقر', 'مقام']
#
# ---------------------
#
# Source Text 92:
# ['يوم', 'تشقق', 'سماء', 'غمام', 'نزل', 'ملأك', 'تنزيل']
#
# Target Text:
# ['انشق', 'سماء', 'يومئذ', 'واهي']
#
# ---------------------
#
# Source Text 93:
# ['ملك', 'يومئذ', 'حق', 'رحمن', 'يوم', 'كافر', 'عسير']
#
# Target Text:
# ['كافر', 'يسير']
#
# ---------------------
#
# Source Text 94:
# ['رب', 'ساجد', 'قيام']
#
# Target Text:
# ['قليل', 'ليل', 'يهجعون']
#
# ---------------------
#
# Source Text 95:
# ['سبحوه', 'بكرة', 'أصيل']
#
# Target Text:
# ['الله', 'مس']
#
# ---------------------
#
# Source Text 96:
# ['تحية', 'يوم', 'ألقى', 'سلام', 'أعد', 'أجر', 'كريم']
#
# Target Text:
# ['سلام', 'قول', 'رب', 'رحيم']
#
# ---------------------
#
# Source Text 97:
# ['أبدى', 'شيء', 'أخفى', 'الله', 'شيء', 'عليم']
#
# Target Text:
# ['خائن', 'أخفى', 'صدر']
#
# ---------------------
#
# Source Text 98:
# ['قال', 'ميعاد', 'يوم', 'تستأخرون', 'ساعة', 'تستقدمون']
#
# Target Text:
# ['ؤخر', 'معدود']
#
# ---------------------
#
# Source Text 99:
# ['قال', 'ميعاد', 'يوم', 'تستأخرون', 'ساعة', 'تستقدمون']
#
# Target Text:
# ['غفر', 'ذنب', 'ؤخر', 'مسمى', 'الله', 'جاء', 'ؤخر']
#
# ---------------------
#
# Source Text 100:
# ['رب', 'سماء', 'أرض', 'رب', 'مشرق']
#
# Target Text:
# ['رب', 'مشرق', 'رب', 'مغرب']
#
# ---------------------
#
# Source Text 101:
# ['رب', 'سماء', 'أرض', 'رب', 'مشرق']
#
# Target Text:
# ['أقسم', 'رب', 'مشرق', 'مغارب', 'قادر']
#
# ---------------------
#
# Source Text 102:
# ['زين', 'سماء', 'دنيا', 'زينة', 'كوكب']
#
# Target Text:
# ['سماء', 'برج', 'زين', 'ناظر']
#
# ---------------------
#
# Source Text 103:
# ['ضرب', 'ناس', 'قرآن', 'تذكر']
#
# Target Text:
# ['ضرب', 'ناس', 'عقل', 'عالم']
#
# ---------------------
#
# Source Text 104:
# ['حميم', 'نار', 'يسجرون']
#
# Target Text:
# ['صب', 'رأس', 'عذاب', 'حميم']
#
# ---------------------
#
# Source Text 105:
# ['حميم', 'نار', 'يسجرون']
#
# Target Text:
# ['طاف', 'حميم', 'آن']
#
# ---------------------
#
# Source Text 106:
# ['تنزيل', 'رحمن', 'رحيم']
#
# Target Text:
# ['تنزيل', 'رب', 'عالم']
#
# ---------------------
#
# Source Text 107:
# ['ذكر', 'قوم', 'سأل']
#
# Target Text:
# ['أنزل', 'كتاب', 'ذكر', 'أفل', 'عقل']
#
# ---------------------
#
# Source Text 108:
# ['أورث', 'قوم', 'آخر']
#
# Target Text:
# ['أورث', 'بنون', 'إسرائيل']
#
# ---------------------
#
# Source Text 109:
# ['ليل', 'سبح', 'أدبار', 'سجود']
#
# Target Text:
# ['ليل', 'تهجد', 'نافلة', 'بعث', 'رب', 'مقام', 'محمود']
#
# ---------------------
#
# Source Text 110:
# ['بحر', 'مسجور']
#
# Target Text:
# ['بحر', 'سجر']
#
# ---------------------
#
# Source Text 111:
# ['أكل', 'اشرب', 'هنيء', 'عمل']
#
# Target Text:
# ['أكل', 'اشرب', 'هنيء', 'أسلفتم', 'يوم', 'خالي']
#
# ---------------------
#
# Source Text 112:
# ['مهطعين', 'داعي', 'قال', 'كافر', 'يوم', 'عسر']
#
# Target Text:
# ['كافر', 'يسير']
#
# ---------------------
#
# Source Text 113:
# ['لؤلؤ', 'مكنون']
#
# Target Text:
# ['بيض', 'مكنون']
#
# ---------------------
#
# Source Text 114:
# ['خلق', 'سماء', 'أرض', 'حق', 'صورة', 'أحسن', 'صورة', 'مصير']
#
# Target Text:
# ['خلق', 'عدل']
#
# ---------------------
#
# Source Text 115:
# ['الله', 'إله', 'الله', 'فليتوكل', 'مؤمن']
#
# Target Text:
# ['رب', 'مشرق', 'مغرب', 'إله', 'وكيل']
#
# ---------------------
#
# Source Text 116:
# ['أعتد', 'كافر', 'سلسلة', 'غل', 'سعير']
#
# Target Text:
# ['غل', 'عنق', 'سلسلة', 'سحب']
#
# ---------------------
#
# Source Text 117:
# ['ليل', 'فاسجد', 'سبح', 'ليل', 'طويل']
#
# Target Text:
# ['قم', 'ليل', 'قليل']
#
# ---------------------
#
# Source Text 118:
# ['نجم', 'طمس']
#
# Target Text:
# ['نجم', 'انكدر']
#
# ---------------------
#
# Source Text 119:
# ['نجم', 'طمس']
#
# Target Text:
# ['كوكب', 'انتثر']
#
# ---------------------
#
# Source Text 120:
# ['جبل', 'نسف']
#
# Target Text:
# ['سأل', 'جبل', 'قال', 'نسف', 'رب', 'نسف']
#
# ---------------------
#
# Source Text 121:
# ['ليل', 'عسعس']
#
# Target Text:
# ['ليل', 'سجى']
#
# ---------------------
#
# Source Text 122:
# ['سمع', 'لاغي']
#
# Target Text:
# ['تنازع', 'كأس', 'لغو', 'تأثيم']
#
# ---------------------
#
# Source Text 123:
# ['سمع', 'لاغي']
#
# Target Text:
# ['سمع', 'لغو', 'تأثيم']
#
# ---------------------
#
# Source Text 124:
# ['أفلح', 'زكى']
#
# Target Text:
# ['أفلح', 'زكى']
#
# ---------------------
#
# Source Text 125:
# ['جمع', 'مال', 'عدد']
#
# Target Text:
# ['جمع', 'أوعى']
#
# ---------------------
#
# Source Text 126:
# ['حض', 'طعام', 'مسكين']
#
# Target Text:
# ['تحاضون', 'طعام', 'مسكين']
#
# ---------------------
#
# Source Text 127:
# ['قول', 'شيء', 'أراد', 'قال']
#
# Target Text:
# ['بسم', 'الله', 'رحمن', 'رحيم', 'قال', 'الله']
#
# ---------------------
#
# Source Text 128:
# ['قول', 'شيء', 'أراد', 'قال']
#
# Target Text:
# ['الله', 'صمد']
#
# ---------------------
#
# Source Text 129:
# ['قول', 'شيء', 'أراد', 'قال']
#
# Target Text:
# ['ولد', 'ولد']
#
# ---------------------
#
# Source Text 130:
# ['قول', 'شيء', 'أراد', 'قال']
#
# Target Text:
# ['كف']
#
# ---------------------
#
# Source Text 131:
# ['أنعام', 'عبرة', 'نسق', 'طون', 'رث', 'دم', 'لبن', 'خالص', 'سائغ', 'شارب']
#
# Target Text:
# ['مرسل', 'هدية', 'ناظر', 'مرسل']
#
# ---------------------
#
# Source Text 132:
# ['أنعام', 'عبرة', 'نسق', 'طون', 'رث', 'دم', 'لبن', 'خالص', 'سائغ', 'شارب']
#
# Target Text:
# ['جاء', 'سليمان', 'قال', 'أتمدونن', 'مال', 'آتى', 'الله', 'خير', 'آتى', 'بهديتكم', 'فرح']
#
# ---------------------
#
# Source Text 133:
# ['أنعام', 'عبرة', 'نسق', 'طون', 'رث', 'دم', 'لبن', 'خالص', 'سائغ', 'شارب']
#
# Target Text:
# ['تذكرة']
#
# ---------------------
#
# Source Text 134:
# ['أنعام', 'عبرة', 'نسق', 'طون', 'رث', 'دم', 'لبن', 'خالص', 'سائغ', 'شارب']
#
# Target Text:
# ['شاء', 'ذكر']
#
# ---------------------
#
# Source Text 135:
# ['قال', 'ملك', 'خزانة', 'رحمة', 'رب', 'لأمسكتم', 'خشية', 'إنفاق', 'إنسان', 'قتور']
#
# Target Text:
# ['مس', 'خير', 'منوع']
#
# ---------------------
#
# Source Text 136:
# ['قال', 'ملك', 'خزانة', 'رحمة', 'رب', 'لأمسكتم', 'خشية', 'إنفاق', 'إنسان', 'قتور']
#
# Target Text:
# ['مصلي']
#
# ---------------------
#
# Source Text 137:
# ['أعجل', 'قوم', 'موسى']
#
# Target Text:
# ['متبر', 'باطل', 'عمل']
#
# ---------------------
#
# Source Text 138:
# ['قال', 'فتنة', 'قوم', 'أضل', 'سامري']
#
# Target Text:
# ['كتاب', 'لوح', 'شيء', 'موعظة', 'تفصيل', 'شيء', 'قوة', 'أمر', 'قوم', 'أحسن', 'سأر', 'دار', 'فاسق']
#
# ---------------------

# %%
# Assuming source_tokens, target_tokens, and relevance_degrees are available
relevance_degree=dataset["relevance_degree"]
# Combine preprocessed texts and relevance degrees
combined_data = []
for idx in range(len(source_tokens)):
    combined_data.append({
        'source': ' '.join(source_tokens[idx]),
        'target': ' '.join(target_tokens[idx]),
        'relevance_degree': relevance_degree[idx]
    })

# %%
from flair.embeddings import WordEmbeddings, DocumentRNNEmbeddings
from flair.data import Sentence
from sklearn.metrics.pairwise import cosine_similarity

# Initialize Flair embeddings with RNN and WordEmbeddings for Arabic
word_embedding = WordEmbeddings('ar')
document_embeddings = DocumentRNNEmbeddings([word_embedding])

# Calculate cosine similarity between source and target for each row
for idx, data in enumerate(combined_data):
    source_text = data['source']
    target_text = data['target']

    # Create Sentence objects for source and target texts
    source_sent = Sentence(source_text)
    target_sent = Sentence(target_text)

    # Embed source and target texts
    document_embeddings.embed(source_sent)
    document_embeddings.embed(target_sent)

    # Extract embeddings
    source_embedding = source_sent.embedding.detach().cpu().numpy().reshape(1, -1)
    target_embedding = target_sent.embedding.detach().cpu().numpy().reshape(1, -1)

    # Calculate cosine similarity between source and target embeddings
    cos_sim = cosine_similarity(source_embedding, target_embedding)[0][0]

    print(f"Row {idx+1}: Cosine Similarity between Source and Target: {cos_sim}")
# Out:
# 2023-12-03 19:32:50,219 https://flair.informatik.hu-berlin.de/resources/embeddings/token/ar-wiki-fasttext-300d-1M.vectors.npy not found in cache, downloading to /tmp/tmpeoryfnlx
# 100%|██████████| 699M/699M [00:41<00:00, 17.8MB/s]
# 2023-12-03 19:33:32,027 copying /tmp/tmpeoryfnlx to cache at /root/.flair/embeddings/ar-wiki-fasttext-300d-1M.vectors.npy
# 2023-12-03 19:33:34,280 removing temp file /tmp/tmpeoryfnlx
# 2023-12-03 19:33:35,254 https://flair.informatik.hu-berlin.de/resources/embeddings/token/ar-wiki-fasttext-300d-1M not found in cache, downloading to /tmp/tmpgv3qkayo
# 100%|██████████| 25.5M/25.5M [00:02<00:00, 10.9MB/s]
# 2023-12-03 19:33:38,368 copying /tmp/tmpgv3qkayo to cache at /root/.flair/embeddings/ar-wiki-fasttext-300d-1M
# 2023-12-03 19:33:38,400 removing temp file /tmp/tmpgv3qkayo
# Row 1: Cosine Similarity between Source and Target: 0.873617947101593
# Row 2: Cosine Similarity between Source and Target: 0.918310821056366
# Row 3: Cosine Similarity between Source and Target: 0.6372454166412354
# Row 4: Cosine Similarity between Source and Target: 0.5826584100723267
# Row 5: Cosine Similarity between Source and Target: 0.5400063991546631
# Row 6: Cosine Similarity between Source and Target: 0.9620764851570129
# Row 7: Cosine Similarity between Source and Target: 0.3159017562866211
# Row 8: Cosine Similarity between Source and Target: 0.5478633642196655
# Row 9: Cosine Similarity between Source and Target: 0.5072602033615112
# Row 10: Cosine Similarity between Source and Target: 0.6623533964157104
# Row 11: Cosine Similarity between Source and Target: 0.585432767868042
# Row 12: Cosine Similarity between Source and Target: 0.6299813985824585
# Row 13: Cosine Similarity between Source and Target: 0.3362356126308441
# Row 14: Cosine Similarity between Source and Target: 0.5830598473548889
# Row 15: Cosine Similarity between Source and Target: 0.39786672592163086
# Row 16: Cosine Similarity between Source and Target: 0.5756141543388367
# Row 17: Cosine Similarity between Source and Target: 0.906660258769989
# Row 18: Cosine Similarity between Source and Target: 0.43703919649124146
# Row 19: Cosine Similarity between Source and Target: 0.1315564513206482
# Row 20: Cosine Similarity between Source and Target: 0.4401959180831909
# Row 21: Cosine Similarity between Source and Target: 0.40825873613357544
# Row 22: Cosine Similarity between Source and Target: 0.3904711604118347
# Row 23: Cosine Similarity between Source and Target: 0.42947107553482056
# Row 24: Cosine Similarity between Source and Target: 0.40721946954727173
# Row 25: Cosine Similarity between Source and Target: 0.4737219214439392
# Row 26: Cosine Similarity between Source and Target: 0.37434542179107666
# Row 27: Cosine Similarity between Source and Target: 0.37801966071128845
# Row 28: Cosine Similarity between Source and Target: 0.24853651225566864
# Row 29: Cosine Similarity between Source and Target: 0.8101133704185486
# Row 30: Cosine Similarity between Source and Target: 0.9085639715194702
# Row 31: Cosine Similarity between Source and Target: 0.9285682439804077
# Row 32: Cosine Similarity between Source and Target: 0.42893239855766296
# Row 33: Cosine Similarity between Source and Target: 0.43247753381729126
# Row 34: Cosine Similarity between Source and Target: 0.40972262620925903
# Row 35: Cosine Similarity between Source and Target: 0.2955359220504761
# Row 36: Cosine Similarity between Source and Target: 0.44629478454589844
# Row 37: Cosine Similarity between Source and Target: 0.5728836059570312
# Row 38: Cosine Similarity between Source and Target: 0.4674340784549713
# Row 39: Cosine Similarity between Source and Target: 0.5434787273406982
# Row 40: Cosine Similarity between Source and Target: 0.6522730588912964
# Row 41: Cosine Similarity between Source and Target: 0.3554782271385193
# Row 42: Cosine Similarity between Source and Target: 0.942266583442688
# Row 43: Cosine Similarity between Source and Target: 0.40630191564559937
# Row 44: Cosine Similarity between Source and Target: 0.38561952114105225
# Row 45: Cosine Similarity between Source and Target: 0.6637428998947144
# Row 46: Cosine Similarity between Source and Target: 0.6785323023796082
# Row 47: Cosine Similarity between Source and Target: 0.46440720558166504
# Row 48: Cosine Similarity between Source and Target: 0.5547218918800354
# Row 49: Cosine Similarity between Source and Target: 0.4619516134262085
# Row 50: Cosine Similarity between Source and Target: 0.9259629845619202
# Row 51: Cosine Similarity between Source and Target: 0.6980235576629639
# Row 52: Cosine Similarity between Source and Target: 0.3924737870693207
# Row 53: Cosine Similarity between Source and Target: 0.6338374614715576
# Row 54: Cosine Similarity between Source and Target: 0.9967070817947388
# Row 55: Cosine Similarity between Source and Target: 0.5718194246292114
# Row 56: Cosine Similarity between Source and Target: 0.4659983515739441
# Row 57: Cosine Similarity between Source and Target: 0.5686406493186951
# Row 58: Cosine Similarity between Source and Target: 0.5498385429382324
# Row 59: Cosine Similarity between Source and Target: 0.32789182662963867
# Row 60: Cosine Similarity between Source and Target: 0.5892663598060608
# Row 61: Cosine Similarity between Source and Target: 0.5491673946380615
# Row 62: Cosine Similarity between Source and Target: 0.9581770300865173
# Row 63: Cosine Similarity between Source and Target: 0.472138911485672
# Row 64: Cosine Similarity between Source and Target: 0.34611430764198303
# Row 65: Cosine Similarity between Source and Target: 0.21518465876579285
# Row 66: Cosine Similarity between Source and Target: 0.34221768379211426
# Row 67: Cosine Similarity between Source and Target: 0.7200347185134888
# Row 68: Cosine Similarity between Source and Target: 0.7584644556045532
# Row 69: Cosine Similarity between Source and Target: 0.6974495649337769
# Row 70: Cosine Similarity between Source and Target: 0.6793346405029297
# Row 71: Cosine Similarity between Source and Target: 0.9714291095733643
# Row 72: Cosine Similarity between Source and Target: 0.6626167893409729
# Row 73: Cosine Similarity between Source and Target: 0.4921419024467468
# Row 74: Cosine Similarity between Source and Target: 0.5105831623077393
# Row 75: Cosine Similarity between Source and Target: 0.3473266363143921
# Row 76: Cosine Similarity between Source and Target: 0.9477680921554565
# Row 77: Cosine Similarity between Source and Target: 0.8900215029716492
# Row 78: Cosine Similarity between Source and Target: 0.5506190061569214
# Row 79: Cosine Similarity between Source and Target: 0.7737942934036255
# Row 80: Cosine Similarity between Source and Target: 0.28994065523147583
# Row 81: Cosine Similarity between Source and Target: 0.6425489187240601
# Row 82: Cosine Similarity between Source and Target: 0.5530170202255249
# Row 83: Cosine Similarity between Source and Target: 0.3847055435180664
# Row 84: Cosine Similarity between Source and Target: 0.1898115873336792
# Row 85: Cosine Similarity between Source and Target: 0.44748061895370483
# Row 86: Cosine Similarity between Source and Target: 0.4905237555503845
# Row 87: Cosine Similarity between Source and Target: 0.588512122631073
# Row 88: Cosine Similarity between Source and Target: 0.3803197145462036
# Row 89: Cosine Similarity between Source and Target: 0.540983259677887
# Row 90: Cosine Similarity between Source and Target: 0.5810093283653259
# Row 91: Cosine Similarity between Source and Target: 0.5683683156967163
# Row 92: Cosine Similarity between Source and Target: 0.44308847188949585
# Row 93: Cosine Similarity between Source and Target: 0.5541328191757202
# Row 94: Cosine Similarity between Source and Target: 0.3757270276546478
# Row 95: Cosine Similarity between Source and Target: 0.32292255759239197
# Row 96: Cosine Similarity between Source and Target: 0.6275365948677063
# Row 97: Cosine Similarity between Source and Target: 0.4114094376564026
# Row 98: Cosine Similarity between Source and Target: 0.5085768699645996
# Row 99: Cosine Similarity between Source and Target: 0.6847137212753296
# Row 100: Cosine Similarity between Source and Target: 0.687483012676239
# Row 101: Cosine Similarity between Source and Target: 0.678326427936554
# Row 102: Cosine Similarity between Source and Target: 0.3093135952949524
# Row 103: Cosine Similarity between Source and Target: 0.5185086727142334
# Row 104: Cosine Similarity between Source and Target: 0.6880340576171875
# Row 105: Cosine Similarity between Source and Target: 0.5253537893295288
# Row 106: Cosine Similarity between Source and Target: 0.5113353729248047
# Row 107: Cosine Similarity between Source and Target: 0.49139735102653503
# Row 108: Cosine Similarity between Source and Target: 0.5434131026268005
# Row 109: Cosine Similarity between Source and Target: 0.5156699419021606
# Row 110: Cosine Similarity between Source and Target: 0.6720961332321167
# Row 111: Cosine Similarity between Source and Target: 0.3621061444282532
# Row 112: Cosine Similarity between Source and Target: 0.48679912090301514
# Row 113: Cosine Similarity between Source and Target: 0.8582625389099121
# Row 114: Cosine Similarity between Source and Target: 0.37964487075805664
# Row 115: Cosine Similarity between Source and Target: 0.5677550435066223
# Row 116: Cosine Similarity between Source and Target: 0.29696017503738403
# Row 117: Cosine Similarity between Source and Target: 0.771630585193634
# Row 118: Cosine Similarity between Source and Target: 0.4849463701248169
# Row 119: Cosine Similarity between Source and Target: 0.2188984900712967
# Row 120: Cosine Similarity between Source and Target: 0.8574536442756653
# Row 121: Cosine Similarity between Source and Target: 0.7394735813140869
# Row 122: Cosine Similarity between Source and Target: 0.3890683650970459
# Row 123: Cosine Similarity between Source and Target: 0.512037992477417
# Row 124: Cosine Similarity between Source and Target: 1.0
# Row 125: Cosine Similarity between Source and Target: 0.4320225119590759
# Row 126: Cosine Similarity between Source and Target: 0.9864816665649414
# Row 127: Cosine Similarity between Source and Target: 0.7365202307701111
# Row 128: Cosine Similarity between Source and Target: 0.3301701545715332
# Row 129: Cosine Similarity between Source and Target: 0.41629528999328613
# Row 130: Cosine Similarity between Source and Target: 0.3836616277694702
# Row 131: Cosine Similarity between Source and Target: 0.46077412366867065
# Row 132: Cosine Similarity between Source and Target: 0.45520997047424316
# Row 133: Cosine Similarity between Source and Target: 0.30327582359313965
# Row 134: Cosine Similarity between Source and Target: 0.4054396450519562
# Row 135: Cosine Similarity between Source and Target: 0.4214334487915039
# Row 136: Cosine Similarity between Source and Target: 0.2016095519065857
# Row 137: Cosine Similarity between Source and Target: 0.42420339584350586
# Row 138: Cosine Similarity between Source and Target: 0.6624889969825745

# %%
from flair.embeddings import WordEmbeddings, DocumentRNNEmbeddings
from flair.data import Sentence
from sklearn.metrics.pairwise import cosine_similarity

from scipy.stats import spearmanr

# Initialize lists to store cosine similarities and relevance degrees
cos_similarities = []
relevance_degrees = []


# Initialize Flair embeddings with RNN and WordEmbeddings for Arabic
word_embedding = WordEmbeddings('ar')
document_embeddings = DocumentRNNEmbeddings([word_embedding])

# Calculate cosine similarity between source and target for each row
for idx, data in enumerate(combined_data):
    source_text = data['source']
    target_text = data['target']

    # Create Sentence objects for source and target texts
    source_sent = Sentence(source_text)
    target_sent = Sentence(target_text)

    # Embed source and target texts
    document_embeddings.embed(source_sent)
    document_embeddings.embed(target_sent)

    # Extract embeddings
    source_embedding = source_sent.embedding.detach().cpu().numpy().reshape(1, -1)
    target_embedding = target_sent.embedding.detach().cpu().numpy().reshape(1, -1)

    # Calculate cosine similarity between source and target embeddings
    cos_sim = cosine_similarity(source_embedding, target_embedding)[0][0]

     # Append cosine similarity to the list
    cos_similarities.append(cos_sim)

    # Append relevance degree to the list
    relevance_degrees.append(data['relevance_degree'])

# Calculate Spearman correlation between cosine similarities and relevance degrees
spearman_corr, spearman_p_value = spearmanr(cos_similarities, relevance_degrees)

print(f"Spearman Correlation: {spearman_corr} (p-value: {spearman_p_value})")
# Out:
# Spearman Correlation: 0.35060795305725545 (p-value: 2.4881994093845047e-05)

# %%
from flair.embeddings import WordEmbeddings, DocumentRNNEmbeddings
from flair.data import Sentence
from sklearn.metrics.pairwise import cosine_similarity
from scipy.stats import pearsonr  # Import Pearson correlation function

# Initialize lists to store cosine similarities and relevance degrees
cos_similarities = []
relevance_degrees = []

# Initialize Flair embeddings with RNN and WordEmbeddings for Arabic
word_embedding = WordEmbeddings('ar')
document_embeddings = DocumentRNNEmbeddings([word_embedding])

# Calculate cosine similarity between source and target for each row
for idx, data in enumerate(combined_data):
    source_text = data['source']
    target_text = data['target']

    # Create Sentence objects for source and target texts
    source_sent = Sentence(source_text)
    target_sent = Sentence(target_text)

    # Embed source and target texts
    document_embeddings.embed(source_sent)
    document_embeddings.embed(target_sent)

    # Extract embeddings
    source_embedding = source_sent.embedding.detach().cpu().numpy().reshape(1, -1)
    target_embedding = target_sent.embedding.detach().cpu().numpy().reshape(1, -1)

    # Calculate cosine similarity between source and target embeddings
    cos_sim = cosine_similarity(source_embedding, target_embedding)[0][0]

    # Append cosine similarity to the list
    cos_similarities.append(cos_sim)

    # Append relevance degree to the list
    relevance_degrees.append(data['relevance_degree'])

# Calculate Pearson correlation between cosine similarities and relevance degrees
pearson_corr, pearson_p_value = pearsonr(cos_similarities, relevance_degrees)

print(f"Pearson Correlation: {pearson_corr} (p-value: {pearson_p_value})")
# Out:
# Pearson Correlation: 0.341207643254556 (p-value: 4.2140458212666696e-05)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
